# %%
import pandas as pd
import numpy as np
import zipfile
import os

# %% [markdown]
# ## Load Datasets

# %%
# !kaggle datasets download nguyenvy/nhanes-19882018
# Out:
# Dataset URL: https://www.kaggle.com/datasets/nguyenvy/nhanes-19882018
# License(s): Attribution 4.0 International (CC BY 4.0)
# Downloading nhanes-19882018.zip to /content
#  99% 870M/875M [00:09<00:00, 106MB/s]
# 100% 875M/875M [00:09<00:00, 97.9MB/s]

# %%
# load data
with zipfile.ZipFile('/content/nhanes-19882018.zip', 'r') as zip_ref:
    zip_ref.extractall('/content/nhanes_19882018_data')

demographics_path = os.path.join('/content/nhanes_19882018_data', 'demographics_clean.csv')
questionnaire_path = os.path.join('/content/nhanes_19882018_data', 'questionnaire_clean.csv')
mortality_path = os.path.join('/content/nhanes_19882018_data', 'mortality_clean.csv')

# Load the CSV file into a DataFrame
demographics_df = pd.read_csv(demographics_path,index_col=0)
questionnaire_df = pd.read_csv(questionnaire_path,index_col=0)
mortality_df = pd.read_csv(mortality_path,index_col=0)

# %%
demographics_df
# Out:
#             SEQN  SEQN_new  AIALANGA  DMAETHN  DMAETHNR  DMARACE  DMARACER  \
# 1            3.0       I-3       NaN      NaN       1.0      NaN       1.0
# 2            4.0       I-4       NaN      NaN       1.0      NaN       1.0
# 3            9.0       I-9       NaN      NaN       3.0      NaN       1.0
# 4           10.0      I-10       NaN      NaN       3.0      NaN       1.0
# 5           11.0      I-11       NaN      NaN       1.0      NaN       1.0
# ...          ...       ...       ...      ...       ...      ...       ...
# 135306  102952.0  C-102952       NaN      NaN       NaN      NaN       NaN
# 135307  102953.0  C-102953       2.0      NaN       NaN      NaN       NaN
# 135308  102954.0  C-102954       1.0      NaN       NaN      NaN       NaN
# 135309  102955.0  C-102955       1.0      NaN       NaN      NaN       NaN
# 135310  102956.0  C-102956       1.0      NaN       NaN      NaN       NaN
#
#         DMDBORN4  DMDCITZN  DMDEDUC  ...  WTMREP43  WTMREP44  WTMREP45  \
# 1            1.0       NaN      NaN  ...       NaN       NaN       NaN
# 2            1.0       NaN      NaN  ...       NaN       NaN       NaN
# 3            1.0       NaN      NaN  ...       NaN       NaN       NaN
# 4            1.0       NaN      NaN  ...       NaN       NaN       NaN
# 5            1.0       NaN      NaN  ...       NaN       NaN       NaN
# ...          ...       ...      ...  ...       ...       ...       ...
# 135306       2.0       1.0      NaN  ...       NaN       NaN       NaN
# 135307       2.0       2.0      NaN  ...       NaN       NaN       NaN
# 135308       1.0       1.0      NaN  ...       NaN       NaN       NaN
# 135309       1.0       1.0      NaN  ...       NaN       NaN       NaN
# 135310       1.0       1.0      NaN  ...       NaN       NaN       NaN
#
#         WTMREP46  WTMREP47  WTMREP48  WTMREP49  WTMREP50  WTMREP51  WTMREP52
# 1            NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 2            NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 3            NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 4            NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 5            NaN       NaN       NaN       NaN       NaN       NaN       NaN
# ...          ...       ...       ...       ...       ...       ...       ...
# 135306       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 135307       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 135308       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 135309       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 135310       NaN       NaN       NaN       NaN       NaN       NaN       NaN
#
# [135310 rows x 281 columns]

# %%
questionnaire_df
# Out:
#             SEQN  SEQN_new  SDDSRVYR  AGQ030  ALQ101  ALQ110  ALQ111  ALQ120Q  \
# 1            3.0       I-3        -1     NaN     NaN     NaN     NaN      NaN
# 2            4.0       I-4        -1     NaN     NaN     NaN     NaN      NaN
# 3            9.0       I-9        -1     NaN     NaN     NaN     NaN      NaN
# 4           10.0      I-10        -1     NaN     NaN     NaN     NaN      NaN
# 5           11.0      I-11        -1     NaN     NaN     NaN     NaN      NaN
# ...          ...       ...       ...     ...     ...     ...     ...      ...
# 134511  102862.0  C-102862        10     NaN     NaN     NaN     NaN      NaN
# 134512  102919.0  C-102919        10     NaN     NaN     NaN     NaN      NaN
# 134513  102927.0  C-102927        10     NaN     NaN     NaN     NaN      NaN
# 134514  102928.0  C-102928        10     NaN     NaN     NaN     NaN      NaN
# 134515  102942.0  C-102942        10     NaN     NaN     NaN     NaN      NaN
#
#         ALQ120U  ALQ130  ...  RHQ710F  RHQ710G  RHQ720  RHQ730  RHQ740  \
# 1           NaN     NaN  ...      NaN      NaN     NaN     NaN     NaN
# 2           NaN     NaN  ...      NaN      NaN     NaN     NaN     NaN
# 3           NaN     NaN  ...      NaN      NaN     NaN     NaN     NaN
# 4           NaN     NaN  ...      NaN      NaN     NaN     NaN     NaN
# 5           NaN     NaN  ...      NaN      NaN     NaN     NaN     NaN
# ...         ...     ...  ...      ...      ...     ...     ...     ...
# 134511      NaN     NaN  ...      NaN      NaN     NaN     NaN     NaN
# 134512      NaN     NaN  ...      NaN      NaN     NaN     NaN     NaN
# 134513      NaN     NaN  ...      NaN      NaN     NaN     NaN     NaN
# 134514      NaN     NaN  ...      NaN      NaN     NaN     NaN     NaN
# 134515      NaN     NaN  ...      NaN      NaN     NaN     NaN     NaN
#
#         RHQ750A  RHQ750B  RHQ750C  VNRHQ51  WHQ030E
# 1           NaN      NaN      NaN      NaN      NaN
# 2           NaN      NaN      NaN      2.0      NaN
# 3           NaN      NaN      NaN      2.0      NaN
# 4           NaN      NaN      NaN      NaN      NaN
# 5           NaN      NaN      NaN      NaN      NaN
# ...         ...      ...      ...      ...      ...
# 134511      NaN      NaN      NaN      NaN      NaN
# 134512      NaN      NaN      NaN      NaN      NaN
# 134513      NaN      NaN      NaN      NaN      NaN
# 134514      NaN      NaN      NaN      NaN      NaN
# 134515      NaN      NaN      NaN      NaN      NaN
#
# [134515 rows x 1444 columns]

# %%
mortality_df
# Out:
#          SEQN SEQN_new  ELIGSTAT  MORTSTAT  UCOD_LEADING  DIABETES  HYPERTEN  \
# 1           1      C-1         2       NaN           NaN       NaN       NaN
# 2           2      C-2         1       1.0           6.0       0.0       0.0
# 3           3      C-3         2       NaN           NaN       NaN       NaN
# 4           4      C-4         2       NaN           NaN       NaN       NaN
# 5           5      C-5         1       0.0           NaN       NaN       NaN
# ...       ...      ...       ...       ...           ...       ...       ...
# 135306  53617  I-53617         2       NaN           NaN       NaN       NaN
# 135307  53618  I-53618         1       1.0           2.0       0.0       0.0
# 135308  53621  I-53621         2       NaN           NaN       NaN       NaN
# 135309  53622  I-53622         2       NaN           NaN       NaN       NaN
# 135310  53623  I-53623         2       NaN           NaN       NaN       NaN
#
#         PERMTH_INT  PERMTH_EXM  SDDSRVYR    VNELIGSTAT        VNMORTSTAT  \
# 1              NaN         NaN         1  Under age 18               NaN
# 2            177.0       177.0         1      Eligible  Assumed deceased
# 3              NaN         NaN         1  Under age 18               NaN
# 4              NaN         NaN         1  Under age 18               NaN
# 5            244.0       244.0         1      Eligible     Assumed alive
# ...            ...         ...       ...           ...               ...
# 135306         NaN         NaN        -1  Under age 18               NaN
# 135307        44.0         NaN        -1      Eligible  Assumed deceased
# 135308         NaN         NaN        -1  Under age 18               NaN
# 135309         NaN         NaN        -1  Under age 18               NaN
# 135310         NaN         NaN        -1  Under age 18               NaN
#
#                        VNUCOD_LEADING VNDIABETES VNHYPERTEN
# 1                                 NaN        NaN        NaN
# 2           Alzheimer’s disease (052)         No         No
# 3                                 NaN        NaN        NaN
# 4                                 NaN        NaN        NaN
# 5                                 NaN        NaN        NaN
# ...                               ...        ...        ...
# 135306                            NaN        NaN        NaN
# 135307  Malignant neoplasms (019-043)         No         No
# 135308                            NaN        NaN        NaN
# 135309                            NaN        NaN        NaN
# 135310                            NaN        NaN        NaN
#
# [135310 rows x 15 columns]
